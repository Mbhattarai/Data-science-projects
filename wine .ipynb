# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
wine = pd.read_csv('/Users/manibhattarai/Desktop/datsets/winequality-red.csv')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
null = wine.isnull()

# %%
sns.heatmap(null, cbar=False,yticklabels=False,cmap='viridis')

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
sns.pairplot(wine)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = wine)

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=wine,x='quality',y='fixed acidity')

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(data=wine,x='quality',y='citric acid')

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(data=wine,x='quality',y='alcohol')

# %%
reiviews = []
def change_qulity():
    for i in wine['quality']:
        if i>= 3 and i<=1:
            return reivews.append('1') 
        elif i>=4 and i<=7:
            return reviews.append('2')
        elif i>= 8 and i<=10:
            return reviews.append('3')
    wine['reviews']= reviews

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
bins = (2,6.5,8)
group_names= ['bad','good']
wine['quality'] = pd.cut(wine['quality'],bins=bins,labels=group_names)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression , LogisticRegression

# %%
le = LabelEncoder()

# %%
le.fit_transform(wine['quality'])
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# ...

# %%
wine['quality'].value_counts()
# Out:
# bad     1382
# good     217
# Name: quality, dtype: int64

# %%
lr = LogisticRegression()

# %%
X = wine.drop('quality',axis=1)
y = wine['quality']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.42, random_state=101)

# %%
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
sc = StandardScaler()

# %%
sc.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sc.fit(X_test)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
lr_predict = lr.predict(X_test)

# %%
print(confusion_matrix(y_test,lr_predict))
# Out:
# [[547  27]
#  [ 70  28]]

# %%
print(classification_report(y_test,lr_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.89      0.95      0.92       574
#         good       0.51      0.29      0.37        98
#
#     accuracy                           0.86       672
#    macro avg       0.70      0.62      0.64       672
# weighted avg       0.83      0.86      0.84       672

# %%
lre = LinearRegression()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rc = RandomForestClassifier(n_estimators = 200)

# %%
rc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rc_predict = rc.predict(X_test)

# %%
print(classification_report(y_test,rc_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.90      0.97      0.93       574
#         good       0.67      0.40      0.50        98
#
#     accuracy                           0.88       672
#    macro avg       0.79      0.68      0.72       672
# weighted avg       0.87      0.88      0.87       672

# %%
print(confusion_matrix(y_test,rc_predict))
# Out:
# [[555  19]
#  [ 59  39]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc = DecisionTreeClassifier()

# %%
dc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dc_predict = dc.predict(X_test)

# %%
print(confusion_matrix(y_test,dc_predict))
# Out:
# [[518  56]
#  [ 42  56]]

# %%
print(classification_report(y_test,dc_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.93      0.90      0.91       574
#         good       0.50      0.57      0.53        98
#
#     accuracy                           0.85       672
#    macro avg       0.71      0.74      0.72       672
# weighted avg       0.86      0.85      0.86       672

# %%
from sklearn.svm import SVC

# %%
svc =SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc_predict = svc.predict(X_test)

# %%
print(classification_report(y_test,svc_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.88      0.98      0.93       574
#         good       0.63      0.19      0.30        98
#
#     accuracy                           0.87       672
#    macro avg       0.76      0.59      0.61       672
# weighted avg       0.84      0.87      0.83       672

# %%
print(confusion_matrix(y_test,svc_predict))
# Out:
# [[563  11]
#  [ 79  19]]

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd = SGDClassifier()

# %%
sgd.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
sgd_predict = sgd.predict(X_test)

# %%
print(classification_report(y_test,sgd_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.86      0.99      0.92       574
#         good       0.42      0.05      0.09        98
#
#     accuracy                           0.85       672
#    macro avg       0.64      0.52      0.50       672
# weighted avg       0.79      0.85      0.80       672

# %%
print(confusion_matrix(y_test,sgd_predict))
# Out:
# [[567   7]
#  [ 93   5]]
